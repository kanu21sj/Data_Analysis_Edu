# %%
from konlpy.tag import Okt

# %%
t = Okt()

# %%
# tokenization 문자열을 여러개 조각으로 쪼개는 함수
tokens_ko = t.nouns("나는 가방에 들어갈거야..가방..가방...진짜야..진짜..진짜..진짜..진짜..오늘은 수요일이야..오늘")
tokens_ko
# Out:
# ['나', '가방', '가방', '가방', '진짜', '진짜', '진짜', '진짜', '진짜', '오늘', '수요일', '오늘']

# %%
import nltk  # 자연어 처리를 위한 객체를 만들어 줌

# %%
ko = nltk.Text(tokens_ko, name='test')  # 테스트라는 큰 말 뭉치가 생김

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm  # 폰트 관련 용도
 
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.font_manager as fm
fontpath = 'C:/Users/CJ/anaconda3/Lib/site-packages/pytagcloud/fonts/NanumGothic.ttf'
font_name = fm.FontProperties(fname=fontpath, size=9).get_name()
plt.rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

#f_path = "/Library/Fonts/AppleGothic.ttf"
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
fm._rebuild() #폰트 설정 반영

# %%
plt.figure(figsize=(14,6))
ko.plot(50)
plt.show()

# %%
musk = """2월 테슬라 결제 비트코인으로 →5월 환경에 악영향 끼쳐서 결제 중단
━
= 엘론 머스크 스페이스X 최고경영자(CEO).  (C) AFP=뉴스1

= 엘론 머스크 스페이스X 최고경영자(CEO). (C) AFP=뉴스1

일론 머스크 테슬라 최고경영자(CEO)가 또다시 트위터로 가상자산(암호화폐) 시장을 뒤흔들었다. 이번엔 '불장'(상승랠리)가 아니라 '찬물'이다.
13일 오전 7시30분(한국시간) 머스크는 자신의 트위터를 통해 "비트코인의 테슬라 결제를 중단한다"고 선언했다.

테슬라가 미국 증권거래위원회(SEC)에 "15억 달러 규모(1조7000억)비트코인을 구매했고 향후 테슬라 자동차 판매를 위한 결제수단으로 비트코인을 사용할 수 있도록 할 계획"이라고 밝힌지 불과 3개월만이다.

머스크가 밝힌 비트코인 결제 중단 이유는 환경 이슈다. 비트코인이 전기를 너무 많이 먹어 환경에 악영향을 미친다는 이유다.

그는 비트코인 채굴에 드는 전기로 화석연료, 특히 석탄의 사용이 급격하게 증가하고 있다며 또 암호화폐의 많은 부분에서 좋은 아이디어지만 환경에 악영향을 미친다고 주장했다.

이에 따라 테슬라는 비트코인 채굴에 지속가능한 에너지가 사용될 때가지 전기차 결제를 중단한다고 선언했다.

특히 머스크는 "우리는 비트코인 사용되는 에너지의 1% 이하를 사용하는 다른 암호화폐를 찾고 있다"며 비트코인이 아닌 다른 암호화폐로 옮길 가능성을 내비쳤다.

━
테슬라, 구매한 비트코인 매각해 1억달러 차익...머스크 "개인보유는 안팔았다" 해명에도 비판 쏟아져
━

(서울=뉴스1) 허경 기자 = 테슬라의 배터리 기술·투자 설명회인 '배터리 데이'가 하루 앞으로 다가오면서 국내 배터리 업체들도 혁신적인 기술이 대거 공개될지 숨죽이며 주목하고 있다. 한국 업체들의 강력한 경쟁자가 될 수 있다는 관측이 나오는 가운데, 장기적으로는 기회가 될 것이란 의견도 나온다.  22일 업계에 따르면 테슬라는 오는 23일 오전 5시30분(현지시간 22일 오후 1시30분) 주주총회를 개최한 직후 '배터리 데이'를 열 예정이다.사진은 이날 서울 청담동의 테슬라 매장. 2020.9.22/뉴스1

(서울=뉴스1) 허경 기자 = 테슬라의 배터리 기술·투자 설명회인 '배터리 데이'가 하루 앞으로 다가오면서 국내 배터리 업체들도 혁신적인 기술이 대거 공개될지 숨죽이며 주목하고 있다. 한국 업체들의 강력한 경쟁자가 될 수 있다는 관측이 나오는 가운데, 장기적으로는 기회가 될 것이란 의견도 나온다. 22일 업계에 따르면 테슬라는 오는 23일 오전 5시30분(현지시간 22일 오후 1시30분) 주주총회를 개최한 직후 '배터리 데이'를 열 예정이다.사진은 이날 서울 청담동의 테슬라 매장. 2020.9.22/뉴스1
머스크와 테슬라의 '뒤통수'는 이번이 처음이 아니다.
테슬라가 보유 중이던 비트코인을 몇개월만에 매각한 것으로 뒤늦게 확인되면서 이에 대한 비판이 일었다.

지난달 26일 테슬라는 실적발표와 함께 "매입했던 15억 달러 어치 비트코인 중 10%를 2억2700만달러에 매각해 1억1000만달러(1220억원) 이익을 얻었다"고 밝혔다.

당시 잭 커크혼 테슬라 최고재무책임자(CFO)"당장 이익을 위해 비트코인을 매수하지는 않았지만 필요가 있어 일부를 매각했다"고 부연했다.

앞선 2월 테슬라가 15억달러(약 1조7000억원)규모의 비트코인을 매입했다고 발표하던 당시 테슬라 측은 "향후 자산의 일부를 디지털 자산에 더 투자할 수 있다"며 "비트코인을 장기 무형자산으로 회계처리 하고 분기별로 가상화폐 보유 현황을 분석할 것"이라고 까지 밝혔다.
특히 머스크는 그동안 비트코인을 직접 홍보하고 본인을 '비트코인의 지지자'라며 주변에 비트코인 매수를 독려해왔다. 올해 초부터는 자신의 트위터 자기소개란에 비트코인이라는 단어를 넣기까지 했다.

올해 초부터 비트코인이 상승랠리는 이어가는 데는 머스크와 테슬라의 '비트코인 공개 홍보' 덕분이라는 분석이 나올 정도였다.

하지만 테슬라가 비트코인 매입을 발표하며 투자 독려를 하던 1분기 동안 비트코인 일부를 매각했다는 사실이 알려지며 머스크는 비판의 중심이 됐다. 머스크는 즉각 반박 트윗을 올려 "내가 개인적으로 보유한 비트코인은 팔지 않았다"며 "테슬라가 비트코인 일부를 매각한 것은 비트코인이 현금으로서 자산 유동성의 가치를 보유하고 있다는 점을 증명하기 위한 것"이라고 전했다.

━
머스크, 도지코인 '희망고문'…SNL에선 "내가 도지 파더(아버지)" vs 방송 끝나곤 "도지코인은 사기"
━


머스크가 최근 가장 많이 언급하는 암호화폐는 비트코인보다 도지코인이다.
도지코인은 온라인에서 인기를 끈 시바견 밈(meme) '도지'를 본 따 만들어진 암호화폐로 지난 2013년 12월 빌리마커스와 잭슨 팔머에 의해 만들어졌다.

도지코인이 유명해진 것은 일론 머스크 테슬라 최고경영자(CEO)가 도지코인을 가장 좋아하는 암호화폐 중 하나로 언급하면서다. 머스크 CEO는 도지코인을 "우리 모두의 암호화폐"라고 지칭하며 응원했다. 떄로 "작은 X(아들)를 위해 도지코인을 샀다" "도지코인을 달 위에 놓을 것" 등의 홍보성 발언을 종종 했다.

특히 지난달 미국 최대 암호화폐 거래사이트 '코인베이스'의 나스닥 상장을 앞두고 도지코인이 폭등했다. 코인베이스는 도지코인을 한 차례 거부한 바 있었다. 당시 트위터 이용자가 머스크에게 "도지코인에게 더 쉽게 접근(투자)할 수 있도록 코인베이스가 도지코인을 상장시켜야 한다고 보는가"라는 질문을 트윗으로 남겼는데 머스크가 "그렇다"고 답변을 남긴 것.

이후 70~80원대 거래되던 도지코인 가격이 급등하기 시작했다.

머스크는 며칠 뒤 또 트위터에 스페인 화가 호안 미로의 '달을 향해 짖는 개'(Dog Barking at the Moon) 사진을 게시하며 "Doge Barking at the Moon."(달은 향해 짖는 도지(개))라는 트위터를 남겼다.

꾸준히 오른 도지코인은 500원대까지 돌파했다. 지난달 27일(현지 시각) 밤 머스크가 다시금 자신의 트윗에 "도지파더(Dodgefather) SNL 5월8일"이라는 짧은 글을 남기면서 잠잠하던 도지코인은 다시 출렁이기 시작했다. 미국 NBC방송 코미디쇼 '새터데이 나이트 라이브'(SNL) 출연을 예고하는 글이었다.

하지만 정작 머스크 출연 이후 도지코인은 9일(현지시간) 한때 35% 이상 급락했다. 머스크는 SNL의 한 코너에서 자신을 '도지코인의 아버지'라 소개하며 도지코인이 "미래의 화폐", "세계를 장악할 금융수단"이라 했다.

이런 설명에도 진행자가 "그래서 사기(hustle) 아니냐"고 재차 묻자 머스크는 마지못해 대답한다는 표정으로 "맞다. 사기"라고 했다. '농담'으로 나온 발언이나 이 방송 전 73센트를 넘어서며 사상 최고가를 돌파한 도지코인 가격은 방송 후 47센트대까지 급락했다."""

# %%
tokens_musk = t.nouns(musk)
tokens_musk
# Out:
# ['테슬라',
#  '결제',
#  '비트코인',
#  '환경',
#  '악',
#  '영향',
#  '결제',
#  '중단',
#  '엘론',
#  '머스크',
#  '스페이스',
#  '최고경영자',
#  '뉴스',
#  '엘론',
#  '머스크',
#  '스페이스',
#  '최고경영자',
#  '뉴스',
#  '론',
#  '머스크',
#  '테슬라',
#  '최고경영자',
#  '트위터',
#  '가상',
#  '자산',
#  '암호',
#  '화폐',
#  '시장',
#  '뒤',
#  '이번',
#  '불',
#  '상승',
#  '랠리',
#  '찬물',
#  '오전',
#  '한국',
#  '시간',
#  '머스크',
#  '자신',
#  '트위터',
#  '통해',
#  '비트코인',
#  '테슬라',
#  '결제',
#  '중단',
#  '고',
#  '선언',
#  '테슬라',
#  '미국',
#  '증권',
#  '거래',
#  '위원회',
#  '달러',
#  '규모',
#  '비트코인',
#  '구매',
#  '향후',
#  '테슬라',
#  '자동차',
#  '판매',
#  '위',
#  '결제',
#  '수단',
#  '비트코인',
#  '사용',
#  '수',
#  '계획',
#  '불과',
#  '개월',
#  '머스크',
#  '비트코인',
#  '결제',
#  '중단',
#  '이유',
#  '환경',
#  '이슈',
#  '비트코인',
#  '전기',
#  '환경',
#  '악',
#  '영향',
#  '이유',
#  '그',
#  '비트코인',
#  '채굴',
#  '전기',
#  '화석연료',
#  '석탄',
#  '사용',
#  '증가',
#  '또',
#  '암호',
#  '화폐',
#  '부분',
#  '아이디어',
#  '환경',
#  '악',
#  '영향',
#  '주장',
#  '이',
#  '테슬라',
#  '비트코인',
#  '채굴',
#  '지속',
#  '에너지',
#  '사용',
#  '때',
#  '가지',
#  '전기차',
#  '결제',
#  '중단',
#  '선언',
#  '머스크',
#  '우리',
#  '비트코인',
#  '사용',
#  '에너지',
#  '이하',
#  '사용',
#  '다른',
#  '암호',
#  '화폐',
#  '며',
#  '비트코인',
#  '다른',
#  '암호',
#  '화폐',
#  '가능성',
#  '내비',
#  '테슬라',
#  '구매',
#  '비트코인',
#  '매각',
#  '차익',
#  '머스크',
#  '개인',
#  '보유',
#  '해명',
#  '비판',
#  '서울',
#  '뉴스',
#  '경',
#  '기자',
#  '테슬라',
#  '배터리',
#  '기술',
#  '투자',
#  '설명',
#  '회',
#  '배터리',
#  '데이',
#  '하루',
#  '앞',
#  '국내',
#  '배터리',
#  '업체',
#  '혁신',
#  '기술',
#  '대거',
#  '공개',
#  '숨죽',
#  '주목',
#  '한국',
#  '업체',
#  '경쟁자',
#  '수',
#  '관측',
#  '가운데',
#  '장기',
#  '기회',
#  '것',
#  '의견',
#  '업계',
#  '테슬라',
#  '오전',
#  '현지',
#  '시간',
#  '오후',
#  '주주총회',
#  '개최',
#  '직후',
#  '배터리',
#  '데이',
#  '를',
#  '열',
#  '예정',
#  '사진',
#  '날',
#  '서울',
#  '청담동',
#  '테슬라',
#  '매장',
#  '뉴스',
#  '서울',
#  '뉴스',
#  '경',
#  '기자',
#  '테슬라',
#  '배터리',
#  '기술',
#  '투자',
#  '설명',
#  '회',
#  '배터리',
#  '데이',
#  '하루',
#  '앞',
#  '국내',
#  '배터리',
#  '업체',
#  '혁신',
#  '기술',
#  '대거',
#  '공개',
#  '숨죽',
#  '주목',
#  '한국',
#  '업체',
#  '경쟁자',
#  '수',
#  '관측',
#  '가운데',
#  '장기',
#  '기회',
#  '것',
#  '의견',
#  '업계',
#  '테슬라',
#  '오전',
#  '현지',
#  '시간',
#  '오후',
#  '주주총회',
#  '개최',
#  '직후',
#  '배터리',
#  '데이',
#  '를',
#  '열',
#  '예정',
#  '사진',
#  '날',
#  '서울',
#  '청담동',
#  '테슬라',
#  '매장',
#  '뉴스',
#  '머스크',
#  '테슬라',
#  '뒤통수',
#  '이번',
#  '처음',
#  '테슬라',
#  '보유',
#  '중',
#  '비트코인',
#  '몇개',
#  '월',
#  '매각',
#  '것',
#  '확인',
#  '이',
#  '대한',
#  '비판',
#  '지난달',
#  '테슬라',
#  '실적',
#  '발표',
#  '매입',
#  '달러',
#  '어치',
#  '비트코인',
#  '중',
#  '를',
#  '매각',
#  '이익',
#  '고',
#  '당시',
#  '잭',
#  '커크',
#  '혼',
#  '테슬라',
#  '최고재',
#  '무책임',
#  '당장',
#  '이익',
#  '위해',
#  '비트코인',
#  '매수',
#  '필요',
#  '일부',
#  '매각',
#  '고',
#  '부연',
#  '테슬라',
#  '약',
#  '규모',
#  '비트코인',
#  '매입',
#  '발표',
#  '당시',
#  '테슬라',
#  '측은',
#  '향후',
#  '자산',
#  '일부',
#  '디지털',
#  '자산',
#  '더',
#  '투자',
#  '수',
#  '며',
#  '비트코인',
#  '장기',
#  '무형',
#  '자산',
#  '회계',
#  '처리',
#  '분기',
#  '별로',
#  '가상',
#  '화폐',
#  '보유',
#  '현황',
#  '분석',
#  '것',
#  '머스크',
#  '그동안',
#  '비트코인',
#  '직접',
#  '홍보',
#  '본인',
#  '비트코인',
#  '지지자',
#  '라며',
#  '주변',
#  '비트코인',
#  '매수',
#  '독려',
#  '올해',
#  '초',
#  '자신',
#  '트위터',
#  '자기',
#  '소개',
#  '란',
#  '비트코인',
#  '단어',
#  '넣기',
#  '올해',
#  '초',
#  '비트코인',
#  '상승',
#  '랠리',
#  '어가',
#  '데',
#  '머스크',
#  '테슬라',
#  '비트코인',
#  '공개',
#  '홍보',
#  '덕분',
#  '분석',
#  '정도',
#  '테슬라',
#  '비트코인',
#  '매입',
#  '발표',
#  '투자',
#  '독려',
#  '동안',
#  '비트코인',
#  '일부',
#  '매각',
#  '사실',
#  '머스크',
#  '비판',
#  '중심',
#  '머스크',
#  '즉각',
#  '반박',
#  '트윗',
#  '내',
#  '개인',
#  '보유',
#  '비트코인',
#  '팔지',
#  '며',
#  '테슬라',
#  '비트코인',
#  '일부',
#  '매각',
#  '것',
#  '비트코인',
#  '현금',
#  '자산',
#  '유동성',
#  '가치',
#  '보유',
#  '점',
#  '증명',
#  '위',
#  '것',
#  '전',
#  '머스크',
#  '도지',
#  '코인',
#  '희망고문',
#  '내',
#  '도지',
#  '아버지',
#  '방송',
#  '도지',
#  '코인',
#  '사기',
#  '머스크',
#  '최근',
#  '가장',
#  '언급',
#  '암호',
#  '화폐',
#  '비트코인',
#  '도지',
#  '코인',
#  '도지',
#  '코인',
#  '온라인',
#  '인기',
#  '끈',
#  '시바견',
#  '밈',
#  '도지',
#  '를',
#  '암호',
#  '화폐',
#  '지난',
#  '스',
#  '잭슨',
#  '머',
#  '도지',
#  '코인',
#  '것',
#  '론',
#  '머스크',
#  '테슬라',
#  '최고경영자',
#  '도지',
#  '코인',
#  '가장',
#  '암호',
#  '화폐',
#  '중',
#  '하나로',
#  '언급',
#  '머스크',
#  '도지',
#  '코인',
#  '우리',
#  '모두',
#  '암호',
#  '화폐',
#  '지칭',
#  '응원',
#  '떄',
#  '아들',
#  '를',
#  '위해',
#  '도지',
#  '코인',
#  '도지',
#  '코인',
#  '달',
#  '위',
#  '것',
#  '등',
#  '홍보',
#  '발언',
#  '종종',
#  '지난달',
#  '미국',
#  '최대',
#  '암호',
#  '화폐',
#  '거래',
#  '사이트',
#  '코인',
#  '베이스',
#  '의',
#  '나스닥',
#  '상장',
#  '도지',
#  '코인',
#  '폭등',
#  '코인',
#  '베이스',
#  '도지',
#  '코인',
#  '차례',
#  '거부',
#  '바',
#  '당시',
#  '트위터',
#  '이용자',
#  '머스크',
#  '도지',
#  '코인',
#  '더',
#  '접근',
#  '투자',
#  '수',
#  '코인',
#  '베이스',
#  '도지',
#  '코인',
#  '상장',
#  '질문',
#  '트윗',
#  '머스크',
#  '고',
#  '답변',
#  '것',
#  '이후',
#  '거래',
#  '도지',
#  '코인',
#  '가격',
#  '급등',
#  '시작',
#  '머스크',
#  '며칠',
#  '뒤',
#  '또',
#  '트위터',
#  '스페인',
#  '화가',
#  '호안',
#  '미로',
#  '달',
#  '향',
#  '개',
#  '사진',
#  '게시',
#  '달',
#  '향',
#  '도지',
#  '개',
#  '트위터',
#  '오른',
#  '도지',
#  '코인',
#  '돌파',
#  '지난달',
#  '현지',
#  '시각',
#  '밤',
#  '머스크',
#  '다시금',
#  '자신',
#  '트윗',
#  '도지',
#  '글',
#  '도지',
#  '코인',
#  '다시',
#  '시작',
#  '미국',
#  '방송',
#  '코미디',
#  '쇼',
#  '새터데이',
#  '나이트',
#  '라이브',
#  '출연',
#  '예고',
#  '글',
#  '정작',
#  '머스크',
#  '출연',
#  '이후',
#  '도지',
#  '코인',
#  '현지',
#  '시간',
#  '이상',
#  '급락',
#  '머스크',
#  '의',
#  '코너',
#  '자신',
#  '도지',
#  '코인',
#  '아버지',
#  '소개',
#  '도지',
#  '코인',
#  '미래',
#  '화폐',
#  '세계',
#  '장악',
#  '금융',
#  '수단',
#  '설명',
#  '진행자',
#  '사기',
#  '고',
#  '재차',
#  '머스크',
#  '대답',
#  '표정',
#  '사기',
#  '농담',
#  '발언',
#  '이',
#  '방송',
#  '전',
#  '센트',
#  '사상',
#  '최고',
#  '돌파',
#  '도지',
#  '코인',
#  '가격',
#  '방송',
#  '후',
#  '센트',
#  '급락']

# %%
musk_ko = nltk.Text(tokens_musk, name='test')

# %%
plt.figure(figsize=(14,6))
musk_ko.plot(50)
plt.show()

# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
import requests
from bs4 import BeautifulSoup
import re

# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
req = requests.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/SSSS.DYNAZENON/%EB%93%B1%EC%9E%A5%EC%9D%B8%EB%AC%BC
# https://namu.wiki/w/%ED%99%A9%EC%A7%84%EC%84%B1
# https://namu.wiki/w/%EC%95%88%EC%A0%84%EC%8B%A0%EB%AC%B8%EA%B3%A0
# https://namu.wiki/w/%EB%B3%B5%ED%95%A9%EB%B6%80%EC%9C%84%20%ED%86%B5%EC%A6%9D%20%EC%A6%9D%ED%9B%84%EA%B5%B0
# https://namu.wiki/w/%EC%84%B8%EA%B3%84%20%EC%B5%9C%EA%B0%95%EC%9D%98%20%EB%85%B8%EB%A0%A5%EA%B0%80%20~%EC%9E%AC%EB%8A%A5%EC%9D%B4%20%5B%EB%85%B8%EB%A0%A5%5D%EC%9D%B4%EC%97%88%EC%9C%BC%EB%AF%80%EB%A1%9C%20%ED%9A%A8%EC%9C%A8%EC%A0%81%EC%9C%BC%EB%A1%9C%20%EA%B7%9C%EA%B2%A9%EC%99%B8%EC%9D%98%20%EB%85%B8%EB%A0%A5%EC%9D%84%20%ED%95%B4%EB%B3%B4%EA%B2%A0%EC%8A%B5%EB%8B%88%EB%8B%A4~

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)  # 스트링에 조인 붙여주면, 스트링 타입이 됨

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# SSSS.DYNAZENON/등장인물
#
#
# SSSS.DYNAZENON/등장인물
#
#
#    상위 문서: SSSS.DYNAZENON1. 가우마 부대2. 괴수 우생 사상3. 주변 인물3.1. 가우마 부대 멤버의 가족3.1.1. 요모기의 가족3.1.2. 유메의 가족3.2. 가우마 부대 멤버의 친구4. 기타 인물4.1. 후지요키다이 합창부4.2. 그 외 인물가우마아사나카 요모기미나미 유메야마나카 코요미아스카가와 치세쥬우가오니쟈무지나시즈무요모기의 어머니 - 성우: 오리카사 후미코아사나카 요모기의 어머니.남편하고는 오래전 이혼했으며 현재는 카미죠와 친근하게 지내고 있다. 요모기를 카미죠 씨와의 외식에 불러서 같이 식사를 한다. 얼핏 보면 요모기의 누나로 보일 만큼 상당한 동안에 미인. 또한 은근히 대인배 기질이 있다.[1] 요모기의 말에 따르면 목소리가 크다는 듯.미나미 카노(南 香乃) - 성우: 사에키 이오리 미나미 유메의 언니.1999년 9월 25일생으로 추정[2],  작중 시점 5년 이상 전에 사망했다. 당시 나이는 현재의 유메와 같은 15세. 유메와 같은 후지요키다이 고교에 다니고 있었다고 한다. 남아있는 달력에 적어놓은 문구들과 그림을 보면 상당히 밝은 성격이었던 것으로 보인다. 다만 유메가 카노의 지인들에게서 언니의 좋은 평을 들을 때마다 의외인듯한 반응을 보이는걸 보면, 어쩌면 유메만이 아는 언니의 다른 일면이 있을지도 모른다. 생전에 유메에게 정기 연주회에 꼭 와줬으면 좋겠다는 말을 남겼지만 그 이전에 사망해 약속을 지키지 못 한 듯하다. 카노의 죽음은 가족 전체에게 커다란 트라우마로 남았고, 유메의 경우 카노의 죽음을 계기로 약속을 지키지 못하는 강박증이 생겼다. 유메가 가지고 다니는 앙크 두 개가 겹쳐진 지혜의 고리 모양의 팬던트는 카노의 유품이다.1화 초반에 요모기와 친구들이 언급한 과거 왕따로 인해 자살한 학생이 카노가 아닐까 하는 추측이 유력하며,[3] 5화의 마지막 장면에서 카노의 지인은 그녀의 사인을 사고사가 아닌 '자살...'이라는 말로 운을 떼다가 여기서 딱 끝나버리는데 실로 악마의 편집이라 할 수 있을 정도. 6화에서 진짜 이지메 당했다는게 나온다. 몰래카메라 형식으로 찍은 비공개 영상인데, 카노를 괴롭히면서도 겉으로는 친한척 하는 모습이 찍혀있다. 유메가 만났던 학교 선배가 생전에 학교 친구들과 좋은 관계를 유지했고 밝은 아이였다고 말했던 것도 모두 사실과 달랐다.[4] 이름의 어원은 동생과 같은 남가일몽.[5]유메의 엄마 - 성우: 이토 시즈카유메의 아빠 - 성우: 오키츠 카즈유키미나미 유메의 부모님.카노의 죽음 이후로 사이가 틀어진 것으로 보인다. 아버지는 카노를 잊으려 노력하는 듯 하지만 어머니의 경우 카노의 방을 5년째 정리하지 않는데다가 매 식사때마다 카노 분의 식기를 한 세트씩 더 준비하는 등 죽은 첫째 딸을 잊지 못하고 있다.메이(鳴衣) - 성우: 타도코로 아즈사미나미 유메의 절친.유메와는 오랜 친구였다고 하며 유메가 농담조로 엄마라고 부를 만큼 터놓은 사이이다. 유메의 강박증으로 인해 학교 내의 소문이 안좋아지는 것을 걱정하고 훈계하지만 효과는 없는듯 하다. 특유의 똥머리와 빨간 안경 덕분에 팬덤에서는 세븐녀(...)라고 불리기도 한다. 유메와는 학교 골목이나 노래방 같은 외진 곳에서만 만나고 있으며 유메 외의 다른 사람들과는 전혀 접점이 없어서 사실은 귀신이거나 아예 유메 눈에만 보이는 환각이 아니냐는 떡밥이 돌고 있지만, 엔딩의 치세 파트에서 유메와 같이 화장품을 고르는 모습이 나오거나 2화에서 요모기의 연락처를 알아낼 때 유메가 지인을 거친 점 등으로 미루어 실존인물이기는 할 것이다.[6]요모기의 친구들늘 5명이 같이 붙어다니는 것으로 보이며, 요모기가 아르바이트로 바쁠 때는 4명만 따로 모인다. 요모기가 다이나제논 활동까지 하게 되면서 따로 있는 시간이 늘어났지만, "요즘 요모기 이상한 친구들 많아졌네" 라면서 황당해 할 뿐 특별히 이유를 추궁하지도 않고, 오히려 요모기에게 먼저 다가가 친목을 유지하는 진짜 친구들. 특히 카네이시의 경우 여러가지 떡밥 때문에 정황상 요모기에게 연심이나 특별한 감정이 있다는 추정도 있다.[7]아와키(淡木) - 성우: 오가사와라 진나즈미(なずみ) - 성우: 카지와라 가쿠토란카(らんか) - 성우: 츠치야 리오카네이시(金石) - 성우: 토노 히카루이나모토 씨카미죠 씨 - 성우: 우치다 유야요모기의 어머니와 사귀고 있는 것으로 보이는 중년 남성. 요모기에게 용돈을 챙겨주지만 요모기는 이를 식당 기부함에 넣어버린다. 요모기를 챙겨주는 듯하면서도 결국 요식행위고 자기 할 말만 해댄다.수영장 감시원 - 성우: 오비 마사야5화에서 출연한 요모기 일행과 시즈무가 놀러간 워터파크의 안전요원. 시즈무를 잡으려고 뻘짓하는 가우마에게 여러번 주의를 준다.[8]비중 없는 단역이지만 성우가 전광초인 그리드맨에서 쇼 나오토를 연기한 오비 마사야. 전작 SSSS.GRIDMAN에 이어 이번에도 특별출연했다. 캐릭터 디자인도 전작의 키보드 손님과 똑같다.타치바나 아라타 - 성우: 호시노 타카노리6화에서 출연한 이나모토 씨의 남편. 술자리에서 코요미를 계속 야마모토라고 잘못 부른다. 이나모토의 남편에다가 자기 가게를 운영하는 어엿한 사회인[9]이라서 코요미에게 본의 아니게 계속해서 열등감을 박아넣는다. 그밖에도 성을 계속해서 잘못 부르거나 끼어든 주제에 자기 혼자 아내하고 이야기를 늘어놓은 등의 무례한 행동을 일삼는다.[10] 겉으로는 정중하지만 사실 코요미에게 눈꼽만큼도 관심이 없고 사실상 무시하는 모습을 보여준다. 위의 카미죠 씨와 비슷한 인간상.[11] 결국 코요미는 못 참고 먼저 술자리를 떴다.합창부 고문 - 성우: 로버트 워터맨후지요키다이 고등학교 합창부의 고문선생님. 유메 언니가 다녔던 5년 전에도 합창부 고문이었다고 한다. 언니에 대해 알아보기 위해 찾아온 유메에게 카나에의 연락처를 전해준다. 참고로 외형과 설정은 담당 성우인 로버트 워터맨을 그대로 복붙해놨다(...).카나에 - 성우: 아사이 아야카후지요키다이 합창부의 졸업생. 유메의 언니인 카노와 같은 시기에 다녔으며 합창부의 분위기 메이커였다고 한다. 언니에 대해 알고 싶다는 유메의 호출에 응해서 카노에 대한 이야기를 해주지만 큰 수확은 없었고, 다른 동창의 전화번호를 유메에게 전해준다. 아는 한도 안에서는 성실히 대답해주려는 태도를 보여 유메도 미소를 지으며 호감을 표했고, 헤어지기 전에는 "카노에 대해 그렇게 여러 사람에게 물어보고 있어?"라고 묻고는 뭔가 더 알아내면 알려주겠으니 힘내라고 응원하며 친절한 선배의 모습을 보여줬다.그러나 다른 동창 후마가 보여준 비공개 영상에서 카노가 사실은 왕따를 당했고[12] 그녀가 주도했다는 사실이 드러났다.[13] 다만 내용을 보면 본인들은 왕따가 아니라 그저 잠깐의 장난이라고 생각한 듯하다. 자각이 없다는 점에서 어떤 의미로는 더 악질이다.[14] 영상도 별 생각없이 올렸다가 카노가 죽자 그제야 심각성을 깨닫고 황급히 비공개로 돌렸을 가능성이 있다. 유메 앞에서 손가락을 떠는 불안증세를 보인 것도, 카노에 대해 그렇게 여러 사람에게 물어보고 있냐고 유메에게 질문한 것도, 양심의 가책이 무의식 중에 발현된 것으로 볼 수 있다.[15]이름의 유래는 문정경중(鼎の軽重を問う, 카나에노 케이쵸오 토우). 남의 실력을 의심해 그 지위를 뒤집으려 하는 행위를 일컫는 말로 카노를 질투해 왕따를 시킨 카나에의 본성을 암시하는 말이다.우리타 - 성우: 아라이 료헤이후지요키다이 합창부의 졸업생. 유메와 요모기에게 카노의 생전 모습이 찍혀있는 유튜브 채널을 알려줬으며, 후마와 만날 수 있게 해줬다.후마 - 성우: 스즈키 료타후지요키다이 합창부의 부부장. 유메에게 카노의 죽음이 이지메에 의한 자살일지도 모른다는 소문을 알려준다. 이후 카노가 죽고나서 비공개로 전환했던 영상을 유메에게 보내준다.센다 후타바후지요키다이 합창부의 당시 부부장. 성격이 좋아서 인기가 많았다고 하며, 유메의 언니인 카노와 연인 관계였다.[16] 카노가 원했던 노래를 정기 연주회에서 부르기로 밀어서 카노와 여자 부원들 사이의 관계가 틀어졌다고 한다.이 문서에 스포일러가 포함되어 있습니다.이 문서가 설명하는 작품이나 인물 등에 대한 줄거리, 결말, 반전 요소 등을 직·간접적으로 포함하고 있습니다.수수께끼의 거 ...

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# %%
# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = requests.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
# 데이터 프레임을 출력합니다.
df.head(5)
# Out:
#                                                title  \
# 0                               SSSS.DYNAZENON/등장인물
# 1                                               황진성
# 2                                             안전신문고
# 3                                       복합부위 통증 증후군
# 4  세계 최강의 노력가 ~재능이 [노력]이었으므로 효율적으로 규격외의 노력을 해보겠습니다~
#
#                                             category  \
# 0                                SSSS.DYNAZENON/등장인물
# 1  1984년 출생대한민국의 축구선수은평구 출신 인물포항 스틸러스/은퇴, 이적AFC 튀...
# 2                                             애플리케이션
# 3                                                희귀병
# 4  일본 라이트 노벨/ㅅ일본 만화/ㅅ일본 판타지 소설소설가가 되자/작품2020년 소설2...
#
#                                         content_text
# 0     상위 문서: SSSS.DYNAZENON1. 가우마 부대2. 괴수 우생 사상3....
# 1  황진성의 수상 이력 ▼2012 K리그 베스트 일레븐 FW  이동국FW  데얀MF  ...
# 2  운영부처행정안전부다운로드안드로이드 IOS홈페이지https://www.safetyre...
# 3  복합부위통증증후군複合部位痛症症候群Complex Regional Pain Syndro...
# 4  세계 최강의 노력가~재능이 [노력]이었으므로 효율적으로 규격외의 노력을 해보겠습니다...

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
#   상위 문서  가우마 부대 괴수 우생 사상 주변 인물 가우마 부대 멤버의 가족 요모기의 가족 유메의 가족 가우마 부대 멤버의 친구 기타 인물 후지요키다이 합창부 그 외 인물가우마아사나카 요모기미나미 유메야마나카 코요미아스카가와 치세쥬우가오니쟈무지나시즈무요모기의 어머니  성우 오리카사 후미코아사나카 요모기의 어머니남편하고는 오래전 이혼했으며 현재는 카미죠와 친근하게 지내고 있다 요모기를 카미죠 씨와의 외식에 불러서 같이 식사를 한다 얼핏 보면 요모기의 누나로 보일 만큼 상당한 동안에 미인 또한 은근히 대인배 기질이 있다 요모기의 말에 따르면 목소리가 크다는 듯미나미 카노   성우 사에키 이오리 미나미 유메의 언니년 월 일생으로 추정  작중 시점 년 이상 전에 사망했다 당시 나이는 현재의 유메와 같은 세 유메와 같은 후지요키다이 고교에 다니고 있었다고 한다 남아있는 달력에 적어놓은 문구들과 그림을 보면 상당히 밝은 성격이었던 것으로 보인다 다만 유메가 카노의 지인들에게서 언니의 좋은 평을 들을 때마다 의외인듯한 반응을 보이는걸 보면 어쩌면 유메만이 아는 언니의 다른 일면이 있을지도 모른다 생전에 유메에게 정기 연주회에 꼭 와줬으면 좋겠다는 말을 남겼지만 그 이전에 사망해 약속을 지키지 못 한 듯하다 카노의 죽음은 가족 전체에게 커다란 트라우마로 남았고 유메의 경우 카노의 죽음을 계기로 약속을 지키지 못하는 강박증이 생겼다 유메가 가지고 다니는 앙크 두 개가 겹쳐진 지혜의 고리 모양의 팬던트는 카노의 유품이다화 초반에 요모기와 친구들이 언급한 과거 왕따로 인해 자살한 학생이 카노가 아닐까 하는 추측이 유력하며 화의 마지막 장면에서 카노의 지인은 그녀의 사인을 사고사가 아닌 자살이라는 말로 운을 떼다가 여기서 딱 끝나버리는데 실로 악마의 편집이라 할 수 있을 정도 화에서 진짜 이지메 당했다는게 나온다 몰래카메라 형식으로 찍은 비공개 영상인데 카노를 괴롭히면서도 겉으로는 친한척 하는 모습이 찍혀있다 유메가 만났던 학교 선배가 생전에 학교 친구들과 좋은 관계를 유지했고 밝은 아이였다고 말했던 것도 모두 사실과 달랐다 이름의 어원은 동생과 같은 남가일몽유메의 엄마  성우 이토 시즈카유메의 아빠  성우 오키츠 카즈유키미나미 유메의 부모님카노의 죽음 이후로 사이가 틀어진 것으로 보인다 아버지는 카노를 잊으려 노력하는 듯 하지만 어머니의 경우 카노의 방을 년째 정리하지 않는데다가 매 식사때마다 카노 분의 식기를 한 세트씩 더 준비하는 등 죽은 첫째 딸을 잊지 못하고 있다메이  성우 타도코로 아즈사미나미 유메의 절친유메와는 오랜 친구였다고 하며 유메가 농담조로 엄마라고 부를 만큼 터놓은 사이이다 유메의 강박증으로 인해 학교 내의 소문이 안좋아지는 것을 걱정하고 훈계하지만 효과는 없는듯 하다 특유의 똥머리와 빨간 안경 덕분에 팬덤에서는 세븐녀라고 불리기도 한다 유메와는 학교 골목이나 노래방 같은 외진 곳에서만 만나고 있으며 유메 외의 다른 사람들과는 전혀 접점이 없어서 사실은 귀신이거나 아예 유메 눈에만 보이는 환각이 아니냐는 떡밥이 돌고 있지만 엔딩의 치세 파트에서 유메와 같이 화장품을 고르는 모습이 나오거나 화에서 요모기의 연락처를 알아낼 때 유메가 지인을 거친 점 등으로 미루어 실존인물이기는 할 것이다요모기의 친구들늘 명이 같이 붙어다니는 것으로 보이며 요모기가 아르바이트로 바쁠 때는 명만 따로 모인다 요모기가 다이나제논 활동까지 하게 되면서 따로 있는 시간이 늘어났지만 요즘 요모기 이상한 친구들 많아졌네 라면서 황당해 할 뿐 특별히 이유를 추궁하지도 않고 오히려 요모기에게 먼저 다가가 친목을 유지하는 진짜 친구들 특히 카네이시의 경우 여러가지 떡밥 때문에 정황상 요모기에게 연심이나 특별한 감정이 있다는 추정도 있다아와키  성우 오가사와라 진나즈미  성우 카지와라 가쿠토란카  성우 츠치야 리오카네이시  성우 토노 히카루이나모토 씨카미죠 씨  성우 우치다 유야요모기의 어머니와 사귀고 있는 것으로 보이는 중년 남성 요모기에게 용돈을 챙겨주지만 요모기는 이를 식당 기부함에 넣어버린다 요모기를 챙겨주는 듯하면서도 결국 요식행위고 자기 할 말만 해댄다수영장 감시원  성우 오비 마사야화에서 출연한 요모기 일행과 시즈무가 놀러간 워터파크의 안전요원 시즈무를 잡으려고 뻘짓하는 가우마에게 여러번 주의를 준다비중 없는 단역이지만 성우가 전광초인 그리드맨에서 쇼 나오토를 연기한 오비 마사야 전작 에 이어 이번에도 특별출연했다 캐릭터 디자인도 전작의 키보드 손님과 똑같다타치바나 아라타  성우 호시노 타카노리화에서 출연한 이나모토 씨의 남편 술자리에서 코요미를 계속 야마모토라고 잘못 부른다 이나모토의 남편에다가 자기 가게를 운영하는 어엿한 사회인이라서 코요미에게 본의 아니게 계속해서 열등감을 박아넣는다 그밖에도 성을 계속해서 잘못 부르거나 끼어든 주제에 자기 혼자 아내하고 이야기를 늘어놓은 등의 무례한 행동을 일삼는다 겉으로는 정중하지만 사실 코요미에게 눈꼽만큼도 관심이 없고 사실상 무시하는 모습을 보여준다 위의 카미죠 씨와 비슷한 인간상 결국 코요미는 못 참고 먼저 술자리를 떴다합창부 고문  성우 로버트 워터맨후지요키다이 고등학교 합창부의 고문선생님 유메 언니가 다녔던 년 전에도 합창부 고문이었다고 한다 언니에 대해 알아보기 위해 찾아온 유메에게 카나에의 연락처를 전해준다 참고로 외형과 설정은 담당 성우인 로버트 워터맨을 그대로 복붙해놨다카나에  성우 아사이 아야카후지요키다이 합창부의 졸업생 유메의 언니인 카노와 같은 시기에 다녔으며 합창부의 분위기 메이커였다고 한다 언니에 대해 알고 싶다는 유메의 호출에 응해서 카노에 대한 이야기를 해주지만 큰 수확은 없었고 다른 동창의 전화번호를 유메에게 전해준다 아는 한도 안에서는 성실히 대답해주려는 태도를 보여 유메도 미소를 지으며 호감을 표했고 헤어지기 전에는 카노에 대해 그렇게 여러 사람에게 물어보고 있어라고 묻고는 뭔가 더 알아내면 알려주겠으니 힘내라고 응원하며 친절한 선배의 모습을 보여줬다그러나 다른 동창 후마가 보여준 비공개 영상에서 카노가 사실은 왕따를 당했고 그녀가 주도했다는 사실이 드러났다 다만 내용을 보면 본인들은 왕따가 아니라 그저 잠깐의 장난이라고 생각한 듯하다 자각이 없다는 점에서 어떤 의미로는 더 악질이다 영상도 별 생각없이 올렸다가 카노가 죽자 그제야 심각성을 깨닫고 황급히 비공개로 돌렸을 가능성이 있다 유메 앞에서 손가락을 떠는 불안증세를 보인 것도 카노에 대해 그렇게 여러 사람에게 물어보고 있냐고 유메에게 질문한 것도 양심의 가책이 무의식 중에 발현된 것으로 볼 수 있다이름의 유래는 문정경중 카나에노 케이쵸오 토우 남의 실력을 의심해 그 지위를 뒤집으려 하는 행위를 일컫는 말로 카노를 질투해 왕따를 시킨 카나에의 본성을 암시하는 말이다우리타  성우 아라이 료헤이후지요키다이 합창부의 졸업생 유메와 요모기에게 카노의 생전 모습이 찍혀있는 유튜브 채널을 알려줬으며 후마와 만날 수 있게 해줬다후마  성우 스즈키 료타후지요키다이 합창부의 부부장 유메에게 카노의 죽음이 이지메에 의한 자살일지도 모른다는 소문을 알려준다 이후 카노가 죽고나서 비공개로 전환했던 영상을 유메에게 보내준다센다 후타바후지요키다이 합창부의 당시 부부장 성격이 좋아서 인기가 많았다고 하며 유메의 언니인 카노와 연인 관계였다 카노가 원했던 노래를 정기 연주회에서 부르기로 밀어서 카노와 여자 부원들 사이의 관계가 틀어졌다고 한다이 문서에 스포일러가 포함되어 있습니다이 문서가 설명하는 작품이나 인물 등에 대한 줄거리 결말 반전 요소 등을 직간접적으로 포함하고 있습니다수수께끼의 거인 화에서는 요모기를 찾아온 가우마를 집안에 들여서 식사 뿐만 아니라 하룻방 재워주기까지 하는데다 화에서는 또 식사를 대접해주기까지 했다 천년 어쩌구 떠들어 대는데도화에서 카미죠와 식사할 때에도 착실한 청년이라고 언급한 걸 보면 가우마가 상당히 마음에 든 듯 하다 첫화 분 초쯤 언니 카노의 방 달력을 보면 년 월의 일 칸에 라는 표시가 있다 일단 화에서 유메 본인 말로는 사고로 죽었다고 한다 유메가 있던 수문이 카노가 사고를 당한 곳이라고 정황상 실족사나 익사로 추정된다 화에선 아예 수문에 떨어져 물에 반만 떠오른 카노의 시신의 모습을 짧게나마 적나라하게 보여준 ...

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#                                            title  \
# 0                                          등장인물
# 1                                           황진성
# 2                                         안전신문고
# 3                                   복합부위 통증 증후군
# 4  세계 최강의 노력가 재능이 노력이었으므로 효율적으로 규격외의 노력을 해보겠습니다
#
#                                             category  \
# 0                                               등장인물
# 1  년 출생대한민국의 축구선수은평구 출신 인물포항 스틸러스은퇴 이적 튀비즈은퇴 이적교토...
# 2                                             애플리케이션
# 3                                                희귀병
# 4         일본 라이트 노벨ㅅ일본 만화ㅅ일본 판타지 소설소설가가 되자작품년 소설년 만화
#
#                                         content_text
# 0    상위 문서  가우마 부대 괴수 우생 사상 주변 인물 가우마 부대 멤버의 가족 요...
# 1  황진성의 수상 이력  리그 베스트 일레븐   이동국  데얀  몰리나  하대성  황진...
# 2  운영부처행정안전부다운로드안드로이드 홈페이지버전  개요 안전신고 대상 신고절차 걸그룹...
# 3  복합부위통증증후군   다른 이름작열통 증후군 동통성 신경영양장애수덱 증후군 수덱 위...
# 4  세계 최강의 노력가재능이 노력이었으므로 효율적으로 규격외의 노력을 해보겠습니다장르판...

# %%
# 각 피처마다 말뭉치를 생성합니다.
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 등장인물 황진성 안전신문고 복합부위 통증 증후군 세계 최강의 노력가 재능이 노력이었으므로 효율적으로 규격외의 노력을 해보겠습니다 고려대학교주변 상권 파일 건담 나드레  류진 도지코인 유엔군사령부 치아교정 철십자 기사단 옴므 코로나바이러스감염증경과년 월 조 바이든년 아틀레티코 마드리드 시즌 호위함대 사우스 파크 어느 날 우리 집 현관으로 멸망이 들어왔다 메가미 디바이스 분류묵향 다크레이디등장인물 카프록시아 바이오하자드 빌리지   성우계 단신 소녀전선    적기사 정난의 변 파이널 판타지  삼각형 정미의병 김태술 용과 같이 유신 페미니즘 나치즘 눈신체파란색 아론 람스데일 쿠키런 킹덤쿠키 제인격    다크나이트던전 앤 파이터스킬 기쁜 우리 토요일 콜 오브 듀티 블랙 옵스 콜드 워장비류주무기 부활차 정두만 미야타 코우키 두꺼운 눈썹캐릭터 산타클로스서브컬쳐 오버레이 유니버스 허수프로게이머 파이널 판타지  에버 크라이시스 아틀레티코 마드리드 시즌리그 구해줘 크리스핀 프리먼 김나라 벨벳케이크맛 쿠키 헤일리   매더스 국회의원 손 마사요시 타이탄다크 스토리 시리즈 레이븐엘소드레이지 하츠 배재대학교 더미김나라개를 낳았다  머리카락빨간색캐릭터 개성나의 히어로 아카데미아 다이루크 아스날  시즌리그   미인 그려놓고 평범하다고 우기기 도날드 덕 가족의 모험등장인물 후지 키세키우마무스메   파일 건담 버체  크리스토퍼 파이크 청기사다크 스토리 시리즈

# %%
from konlpy.tag import Okt
from collections import Counter

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)

# %%
count
# Out:
# Counter({'상위': 58,
#          '문서': 1059,
#          '부대': 52,
#          '괴수': 2,
#          '생': 80,
#          '사상': 45,
#          '주변': 103,
#          '인물': 180,
#          '멤버': 106,
#          '가족': 157,
#          '모기': 28,
#          '유메': 43,
#          '친구': 83,
#          '기타': 87,
#          '후지': 28,
#          '키다': 7,
#          '합창': 9,
#          '부': 203,
#          '그': 1094,
#          '외': 150,
#          '우마': 18,
#          '아사나': 2,
#          '카': 296,
#          '미나미': 9,
#          '유': 76,
#          '마나': 54,
#          '코': 429,
#          '미아스': 1,
#          '카가와': 1,
#          '쥬': 7,
#          '가오니': 1,
#          '쟈': 4,
#          '무지': 38,
#          '나시': 4,
#          '무': 126,
#          '어머니': 62,
#          '성우': 332,
#          '오리': 38,
#          '후': 492,
#          '미코': 10,
#          '남편': 28,
#          '이혼': 4,
#          '현재': 168,
#          '카미': 29,
#          '씨': 18,
#          '외식': 1,
#          '식사': 16,
#          '얼핏': 3,
#          '누나': 5,
#          '만큼': 115,
#          '동안': 144,
#          '미인': 152,
#          '또한': 323,
#          '은근': 14,
#          '대인배': 1,
#          '기질': 3,
#          '말': 518,
#          '목소리': 50,
#          '듯': 278,
#          '카노': 42,
#          '사': 32,
#          '이오리': 2,
#          '언니': 20,
#          '년': 1116,
#          '월': 896,
#          '일생': 9,
#          '추정': 43,
#          '중': 807,
#          '시점': 57,
#          '이상': 258,
#          '전': 478,
#          '사망': 57,
#          '당시': 212,
#          '나이': 77,
#          '세': 186,
#          '고교': 30,
#          '달력': 2,
#          '문구': 7,
#          '그림': 61,
#          '성격': 66,
#          '것': 2013,
#          '다만': 221,
#          '지인': 10,
#          '평': 52,
#          '때': 910,
#          '의외': 6,
#          '반응': 100,
#          '어쩌면': 9,
#          '다른': 481,
#          '일면': 2,
#          '생전': 4,
#          '정기': 24,
#          '연주회': 2,
#          '꼭': 25,
#          '이전': 974,
#          '약속': 23,
#          '못': 289,
#          '죽음': 33,
#          '전체': 171,
#          '트라우마': 12,
#          '경우': 703,
#          '계기': 19,
#          '강박증': 2,
#          '가지': 255,
#          '앙크': 2,
#          '두': 175,
#          '개': 445,
#          '겹': 25,
#          '지혜': 4,
#          '고리': 6,
#          '모양': 63,
#          '팬던': 1,
#          '유품': 1,
#          '다화': 18,
#          '초반': 104,
#          '언급': 201,
#          '과거': 80,
#          '왕따': 7,
#          '자살': 26,
#          '학생': 48,
#          '추측': 34,
#          '화의': 6,
#          '마지막': 191,
#          '장면': 120,
#          '그녀': 79,
#          '사인': 14,
#          '사고사': 1,
#          '말로': 20,
#          '운': 32,
#          '여기': 162,
#          '실로': 10,
#          '악마': 40,
#          '편집': 16,
#          '수': 1613,
#          '정도': 571,
#          '화': 197,
#          '진짜': 43,
#          '이지메': 7,
#          '몰래카메라': 1,
#          '형식': 25,
#          '비공개': 6,
#          '영상': 110,
#          '겉': 8,
#          '친한척': 1,
#          '모습': 408,
#          '학교': 370,
#          '선배': 28,
#          '관계': 79,
#          '유지': 98,
#          '아이': 161,
#          '모두': 259,
#          '사실': 303,
#          '이름': 196,
#          '어원': 1,
#          '동생': 23,
#          '남가일몽유메': 1,
#          '엄마': 24,
#          '이토': 19,
#          '카유메': 1,
#          '아빠': 13,
#          '키츠': 3,
#          '유키': 31,
#          '부모님': 12,
#          '이후': 592,
#          '사이': 126,
#          '아버지': 107,
#          '노력': 48,
#          '방': 69,
#          '정리': 29,
#          '매': 60,
#          '분': 244,
#          '식기': 3,
#          '세트': 40,
#          '더': 657,
#          '준비': 52,
#          '등': 787,
#          '첫째': 7,
#          '딸': 70,
#          '메이': 46,
#          '타도': 2,
#          '코로': 1,
#          '아즈사': 2,
#          '절친': 4,
#          '농담': 16,
#          '조로': 3,
#          '터': 264,
#          '내의': 12,
#          '소문': 18,
#          '걱정': 33,
#          '훈계': 1,
#          '효과': 299,
#          '특유': 37,
#          '똥': 11,
#          '머리': 169,
#          '안경': 27,
#          '덕분': 83,
#          '팬덤': 19,
#          '세븐': 13,
#          '녀': 17,
#          '불리': 20,
#          '기도': 120,
#          '골목': 9,
#          '노래방': 5,
#          '외진': 2,
#          '곳': 139,
#          '사람': 352,
#          '전혀': 84,
#          '접점': 3,
#          '귀신': 23,
#          '거나': 114,
#          '아예': 103,
#          '눈': 168,
#          '환각': 4,
#          '떡밥': 20,
#          '엔딩': 22,
#          '파트': 27,
#          '화장품': 5,
#          '연락처': 3,
#          '점': 380,
#          '실존': 7,
#          '늘': 20,
#          '명': 983,
#          '보이': 106,
#          '아르바이트': 1,
#          '이나': 37,
#          '제논': 3,
#          '활동': 93,
#          '시간': 518,
#          '요즘': 17,
#          '뿐': 96,
#          '이유': 143,
#          '추궁': 1,
#          '오히려': 95,
#          '먼저': 73,
#          '친목': 3,
#          '시': 689,
#          '여러가지': 17,
#          '때문': 760,
#          '정': 162,
#          '황상': 10,
#          '심': 37,
#          '감정': 37,
#          '키': 302,
#          '오가사와라': 1,
#          '진': 162,
#          '나즈': 2,
#          '가쿠토': 1,
#          '란카': 2,
#          '츠치야': 3,
#          '리오': 12,
#          '토노': 2,
#          '히카루': 6,
#          '모토': 14,
#          '우치다': 1,
#          '유야': 2,
#          '중년': 20,
#          '남성': 196,
#          '용돈': 1,
#          '식당': 15,
#          '기부': 16,
#          '함': 76,
#          '식': 133,
#          '행위': 28,
#          '자기': 111,
#          '해': 73,
#          '수영장': 1,
#          '감시': 16,
#          '오비': 3,
#          '마사': 38,
#          '야화': 1,
#          '출연': 92,
#          '일행': 58,
#          '무가': 1,
#          '간': 59,
#          '워터파크': 1,
#          '안전': 44,
#          '요원': 62,
#          '뻘짓하': 1,
#          '번': 1789,
#          '주의': 246,
#          '비중': 24,
#          '단역': 7,
#          '전광': 1,
#          '초인': 4,
#          '그리드': 2,
#          '맨': 49,
#          '쇼': 217,
#          '나': 167,
#          '오토': 18,
#          '연기': 68,
#          '전작': 83,
#          '이번': 152,
#          '특별출연': 2,
#          '캐릭터': 551,
#          '디자인': 69,
#          '보드': 15,
#          '손님': 11,
#          '타치바나': 9,
#          '아라타': 6,
#          '호시노': 5,
#          '리화': 1,
#          '술자리': 4,
#          '요미': 6,
#          '계속': 148,
#          '야마모토': 3,
#          '잘못': 26,
#          '가게': 33,
#          '운영': 70,
#          '사회인': 1,
#          '본의': 8,
#          '열등감': 9,
#          '박아': 8,
#          '성': 143,
#          '주제': 23,
#          '혼자': 58,
#          '아내': 32,
#          '이야기': 116,
#          '행동': 75,
#          '일삼': 4,
#          '눈꼽': 1,
#          '관심': 46,
#          '무시': 71,
#          '위': 1051,
#          '인간': 65,
#          '참고': 187,
#          '다합': 1,
#          '창부': 1,
#          '고문': 13,
#          '로버트': 14,
#          '워터맨': 2,
#          '고등학교': 27,
#          '부의': 23,
#          '선생님': 8,
#          '대해': 199,
#          '위해': 337,
#          '카나': 20,
#          '외형': 41,
#          '설정': 355,
#          '담당': 75,
#          '그대로': 129,
#          '복': 8,
#          '아사': 15,
#          '아야카': 13,
#          '졸업생': 6,
#          '시기': 54,
#          '분위기': 83,
#          '메이커': 78,
#          '알': 187,
#          '호출': 2,
#          '응': 8,
#          '대한': 403,
#          '해주': 1,
#          '수확': 5,
#          '동창': 8,
#          '전화번호': 1,
#          '한도': 6,
#          '안': 321,
#          '대답': 13,
#          '태도': 31,
#          '미소': 14,
#          '호감': 9,
#          '표': 46,
#          '여러': 101,
#          '뭔가': 13,
#          '응원': 18,
#          '마가': 6,
#          '내용': 346,
#          '본인': 162,
#          '잠깐': 29,
#          '장난': 31,
#          '생각': 249,
#          '자각': 40,
#          '의미': 118,
#          '악질': 4,
#          '별': 131,
#          '심각': 7,
#          '황': 15,
#          '가능성': 89,
#          '앞': 139,
#          '손가락': 13,
#          '불안': 10,
#          '증세': 4,
#          '질문': 21,
#          '양심': 4,
#          '가책': 3,
#          '무의식': 1,
#          '발현': 8,
#          '볼': 213,
#          '유래': 13,
#          '정경': 6,
#          '에노': 3,
#          '케이': 47,
#          '토우': 13,
#          '남': 49,
#          '실력': 43,
#          '의심': 46,
#          '지위': 14,
#          '질투': 2,
#          '본성': 7,
#          '암시': 10,
#          '다우': 3,
#          '리타': 9,
#          '라이': 61,
#          '료헤': 1,
#          '유튜브': 33,
#          '채널': 21,
#          '후마': 4,
#          '만날': 7,
#          '스즈키': 8,
#          '료': 24,
#          '부부': 19,
#          '일지': 13,
#          '전환': 26,
#          '타바': 1,
#          '인기': 88,
#          '연인': 6,
#          '노래': 31,
#          '여자': 88,
#          '부원': 3,
#          '스포일러': 25,
#          '포함': 143,
#          '설명': 80,
#          '작품': 145,
#          '줄거리': 17,
#          '결말': 21,
#          '반전': 25,
#          '요소': 69,
#          '직': 36,
#          '간접': 20,
#          '수수께끼': 2,
#          '거인': 55,
#          '가우': 2,
#          '집안': 12,
#          '룻방': 1,
#          '또': 115,
#          '대접': 9,
#          '천년': 12,
#          '어쩌구': 1,
#          '도화': 1,
#          '청년': 15,
#          '걸': 248,
#          '마음': 47,
#          '초': 345,
#          '일': 804,
#          '칸': 60,
#          '표시': 101,
#          '일단': 89,
#          '사고': 74,
#          '수문': 2,
#          '당한': 14,
#          '실족': 1,
#          '사나': 43,
#          '익사': 3,
#          '물': 59,
#          '반': 60,
#          '시신': 4,
#          '수도': 122,
#          '애': 42,
#          '실제': 206,
#          '상황': 308,
#          '경계': 14,
#          '가해자': 3,
#          '자신': 435,
#          '상대': 253,
#          '거': 117,
#          '진심': 18,
#          '우리': 101,
#          '타가': 37,
#          '친': 26,
#          '이': 1230,
#          '문제': 289,
#          '대사': 91,
#          '상당수': 19,
#          '음': 41,
#          '난': 90,
#          '겉도': 1,
#          '존재': 236,
#          '직접': 141,
#          '방법': 87,
#          '몸': 86,
#          '시야': 28,
#          '듯이': 10,
#          '보': 49,
#          '주로': 86,
#          '풀': 52,
#          '막': 44,
#          '동맹': 23,
#          '출현': 14,
#          '그냥': 137,
#          '보기': 83,
#          '소유': 19,
#          '업체': 12,
#          '착용': 59,
#          '시계': 3,
#          '롤렉스': 1,
#          '왼손': 4,
#          '악수': 4,
#          '의견': 62,
#          '보통': 79,
#          '설령': 8,
#          '왼손잡이': 1,
#          '오른손': 4,
#          '예의': 4,
#          '의식': 28,
#          '여부': 21,
#          '신경': 44,
#          '손': 149,
#          '방향': 62,
#          '상식': 3,
#          '외간': 1,
#          '남자': 100,
#          '술': 77,
#          '역정': 1,
#          '마당': 3,
#          '선': 142,
#          '보살': 2,
#          '점도': 10,
#          '추후': 10,
#          '전개': 42,
#          '따라서': 57,
#          '몰래': 28,
#          '앞서': 37,
#          '호의': 15,
#          '평가': 202,
#          '꼼지락': 1,
#          '거짓말': 16,
#          '부분': 519,
#          '다시': 262,
#          '피해자': 12,
#          '이해': 35,
#          '죄': 25,
#          '일부러': 20,
#          '소개': 48,
#          '줄': 86,
#          '필요': 64,
#          '단서': 12,
#          '탓': 57,
#          '한편': 71,
#          '설마': 9,
#          '리가': 26,
#          '부정': 36,
#          '지금': 109,
#          '대체로': 18,
#          '은': 128,
#          '확정': 66,
#          '일부': 150,
#          '판': 1100,
#          '문단': 1224,
#          '역사': 931,
#          '가기': 31,
#          '접기': 271,
#          '황진성': 38,
#          '수상': 22,
#          '이력': 7,
#          '리그': 203,
#          '베스트': 18,
#          '일레븐': 23,
#          '이동국': 2,
#          '데얀': 2,
#          '몰리나': 4,
#          '하대성': 2,
#          '이근호': 2,
#          '아디': 2,
#          '정인환': 2,
#          '곽태휘': 2,
#          '김창수': 2,
#          '김용대': 2,
#          '대한민국': 86,
#          '축구선수': 4,
#          '출생': 16,
#          '서울특별시': 10,
#          '은평구': 1,
#          '국적': 23,
#          '신체': 52,
#          '조건': 47,
#          '포지션': 59,
#          '공격': 754,
#          '미드필더': 20,
#          '윙어': 4,
#          '번호': 26,
#          '포항': 46,
#          '스틸러스': 9,
#          '비즈': 8,
#          '교토': 22,
#          '상가': 6,
#          '오카야마': 4,
#          '성남': 9,
#          '강원': 23,
#          '한국': 265,
#          '축구': 18,
#          '국가대표팀': 4,
#          '번유': 1,
#          '소년': 50,
#          '클럽': 21,
#          '서울': 113,
#          '갈현': 1,
#          '초등학교': 7,
#          '경신': 1,
#          '중학교': 17,
#          '목동': 3,
#          '정보산업': 1,
#          '제철': 1,
#          '공업고등학교': 1,
#          '소속': 81,
#          '국가대표': 4,
#          '경기': 780,
#          '골': 114,
#          '종교': 35,
#          '개신교': 14,
#          '개요': 60,
#          '경력': 21,
#          '시즌': 922,
#          '스토브': 2,
#          '여담': 82,
#          '관련': 197,
#          '프랜차이즈': 8,
#          '스타': 181,
#          '테크': 62,
#          '션': 94,
#          '김재성': 9,
#          '가장': 317,
#          '유리': 35,
#          '철강왕': 1,
#          '진화': 11,
#          '사나이': 2,
#          '별명': 32,
#          '카카': 1,
#          '패스': 153,
#          '스피드': 213,
#          '스타일': 50,
#          '포철공고': 1,
#          '입학': 11,
#          '뒤': 231,
#          '구단': 20,
#          '지원': 78,
#          '브라질': 8,
#          '유학': 7,
#          '바': 86,
#          '능력': 198,
#          '스탯': 28,
#          '좀': 115,
#          '컵': 24,
#          '대회': 30,
#          '리그컵': 2,
#          '를': 453,
#          '제외': 158,
#          '정규': 41,
#          '소화': 18,
#          '프로': 65,
#          '단': 151,
#          '당장': 25,
#          '비교': 102,
#          '출장': 18,
#          '빈도': 6,
#          '수가': 83,
#          '감안': 21,
#          '부상': 143,
#          '따바레즈': 1,
#          '윙': 54,
#          '선수': 215,
#          '공존': 5,
#          '경쟁': 53,
#          '이외': 39,
#          '잔': 26,
#          '기복': 9,
#          '만하': 15,
#          '지난': 79,
#          '세르': 114,
#          '지오': 4,
#          '파리아스': 1,
#          '팀': 422,
#          '황금기': 2,
#          '레모스': 2,
#          '베이라': 1,
#          '최악': 45,
#          '반기': 22,
#          '호흡': 13,
#          '데닐손': 1,
#          '스테보': 1,
#          '모따': 3,
#          '설기현': 2,
#          '달리기': 3,
#          '감독': 88,
#          '웨이': 18,
#          '뻥': 7,
#          '구사': 10,
#          '박창현': 1,
#          '대행': 13,
#          '추스려': 1,
#          '바닥': 25,
#          '순위': 61,
#          '위로': 56,
#          '챔스': 18,
#          '강': 97,
#          '선방': 33,
#          '후반기': 16,
#          '어시스트': 34,
#          '기록': 158,
#          '팀내': 6,
#          '포인트': 168,
#          '포스코': 1,
#          '포텐셜': 8,
#          '폭발': 205,
#          '괴물': 23,
#          '변신': 14,
#          '황금': 32,
#          '구축': 14,
#          '일조': 8,
#          '신형민': 2,
#          '편대': 1,
#          '수비': 127,
#          '공': 38,
#          '원래': 91,
#          '개팀': 1,
#          '추진': 23,
#          '황선홍': 1,
#          '부임': 8,
#          '주전': 24,
#          '자리': 106,
#          '보장': 24,
#          '애초': 29,
#          '잔류': 6,
#          '동의': 14,
#          '중심': 56,
#          '러시앤캐시': 1,
#          '핵': 15,
#          '발돋움': 1,
#          '중반': 26,
#          '기': 308,
#          '상주': 3,
#          '상무': 7,
#          '군입대': 2,
#          '내내': 32,
#          '짝': 16,
#          '활약': 107,
#          '자지라': 1,
#          '적함': 1,
#          '시피': 4,
#          '유스': 11,
#          '출신': 76,
#          '면서': 37,
#          '신인': 25,
#          '후보': 24,
#          '이명주': 6,
#          '신진호': 9,
#          '잡고': 22,
#          '공익': 14,
#          '복무': 8,
#          '황지수': 5,
#          '가중': 2,
#          '부담': 29,
#          '정평': 3,
#          '답': 49,
#          '수비수': 7,
#          '게': 198,
#          '아시안컵': 1,
#          '문창진': 4,
#          '포텐': 8,
#          '건': 236,
#          '덤': 32,
#          '성장': 23,
#          '약간': 76,
#          '정체': 42,
#          '대체': 41,
#          '찌': 1,
#          '감치': 1,
#          '카타르': 6,
#          '임대': 97,
#          '지라': 7,
#          '어찌': 13,
#          '김승대': 4,
#          '빈': 33,
#          '마르지': 2,
#          '샘물': 9,
#          '제발': 5,
#          '공격수': 8,
#          '쪽': 167,
#          '역시': 207,
#          '경고': 40,
#          '누적': 15,
#          '월드컵': 2,
#          '최종': 75,
#          '예선': 6,
#          '최강희': 2,
#          '합류': 23,
#          '뉴스': 26,
#          '바로': 166,
#          '다음': 132,
#          '도움': 86,
#          '자축': 1,
#          '포': 75,
#          '작렬': 1,
#          '승리': 175,
#          '라운드': 124,
#          '연속': 51,
#          '주간': 5,
#          '선정': 62,
#          '최고': 99,
#          '전성기': 13,
#          '누리': 3,
#          '득점': 122,
#          '최': 50,
#          '가입': 11,
#          '최초': 46,
#          '승강제': 1,
#          '시행': 9,
#          '스플릿': 4,
#          '시스템': 76,
#          '도입': 12,
#          '치루': 2,
#          '살인': 20,
#          '일정': 56,
#          '임': 205,
#          '가운데': 40,
#          '선발': 104,
#          '타임': 58,
#          '경기도': 28,
#          '악재': 10,
#          '마': 142,
#          '무조건': 41,
#          '군대': 57,
#          '가야': 17,
#          '그것': 54,
#          '경찰청': 1,
#          '제한': 38,
#          '성공': 32,
#          '복귀': 82,
#          '전례': 3,
#          '입대': 21,
#          '예정자': 3,
#          '해외': 37,
#          '여권': 7,
#          '발급': 3,
#          '즉': 64,
#          '훈련': 54,
#          '및': 251,
#          '챔피언스': 36,
#          '원정': 96,
#          '출전': 105,
#          '로': 416,
#          '이적': 111,
#          '억': 35,
#          '협상': 13,
#          '연봉': 15,
#          '대박': 7,
#          '인상': 72,
#          '계약': 81,
#          '자체': 181,
#          '난항': 3,
#          '입장': 89,
#          '달리': 151,
#          '재정': 5,
#          '편': 277,
#          '팬': 182,
#          '프렌': 2,
#          '차': 266,
#          '이즈': 17,
#          '터키': 9,
#          '병역법': 1,
#          '참가': 18,
#          '재계약': 10,
#          '합의': 419,
#          '제대': 10,
#          '의문': 21,
#          '얼마나': 31,
#          '생명': 17,
#          '갈림길': 1,
#          '설': 38,
#          '챌린저스리그': 1,
#          '병역': 5,
#          '전지': 2,
#          '첫': 171,
#          '베이징': 2,
#          '궈안': 1,
#          '후반': 152,
#          '교체': 142,
#          '클래스': 7,
#          '몸소': 1,
#          '막판': 21,
#          '클래식': 27,
#          '개막전': 10,
#          '상암': 1,
#          '윈윈': 1,
#          '스틸야드': 2,
#          '동해안': 1,
#          '더비': 16,
#          '전반': 147,
#          '코너킥': 14,
#          '고무열': 2,
#          '도우': 9,
#          '후계': 9,
#          '무럭무럭': 2,
#          '국': 30,
#          '급': 59,
#          '옆': 62,
#          '스틸': 20,
#          '타카': 21,
#          '지휘': 33,
#          '관': 116,
#          '맹활약': 6,
#          '도지': 61,
#          '횟수': 37,
#          '들락날락': 1,
#          '시작': 275,
#          '차출': 2,
#          '달': 117,
#          '전남': 20,
#          '멀티골': 8,
#          '부산': 31,
#          '윌리엄': 13,
#          '태클': 7,
#          '치명': 50,
#          '무릎': 9,
#          '마감': 12,
#          '필린': 1,
#          '아웃': 15,
#          '상태': 299,
#          '멘붕': 6,
#          '거기': 56,
#          '추가': 266,
#          '검진': 4,
#          '십자': 20,
#          '인대': 1,
#          '손상': 16,
#          '멘탈': 12,
#          '소멸': 10,
#          '직전': 41,
#          '하반기': 3,
#          '버티고': 8,
#          '군': 44,
#          '가슴': 53,
#          '더블': 14,
#          '우승': 68,
#          '달성': 48,
#          '비록': 18,
#          '울산': 19,
#          '기쁨': 9,
#          '기준': 192,
#          '최다인': 1,
#          '종료': 74,
#          '자격': 11,
#          '그동안': 14,
#          '공헌': 5,
#          '주기': 17,
#          '바랬으': 1,
#          '고액': 6,
#          '전역': 12,
#          '포화': 2,
#          '최소': 31,
#          '개활': 1,
#          '재활': 8,
#          '메달': 1,
#          '려': 10,
#          '잡': 22,
#          '여력': 1,
#          '미계': 1,
#          '약': 68,
#          '대상자': 1,
#          '등록': 12,
#          '와중': 23,
#          '페이스북': 8,
#          '통해': 147,
#          '과도': 13,
#          '언플': 2,
#          '시도': 44,
#          '바람': 100,
#          '동정': 5,
#          '여론': 17,
#          '프런트들': 1,
#          '팔': 51,
#          '꿋꿋': 4,
#          '중원': 41,
#          '공신': 10,
#          '서술': 41,
#          '사정': 15,
#          '남아': 12,
#          '달라': 51,
#          '막상': 8,
#          '수급': 3,
#          '곧바로': 7,
#          '팽': 5,
#          '모양새': 7,
#          '프런트': 2,
#          '비난': 16,
#          '대다수': 30,
#          '예산': 10,
#          '감축': 5,
#          '신화용': 2,
#          '개월': 29,
#          '결장': 24,
#          '장담': 4,
#          '네임드': 6,
#          '끝': 104,
#          '따름': 1,
#          '다행': 6,
#          '면제': 2,
#          '판정': 139,
#          '아쉬움': 8,
#          '속': 166,
#          '손수': 2,
#          ...})

# %%
# 한글자 키워드를 제거합니다.
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'문단': 1224, '문서': 1059, '이전': 974, '역사': 931, '시즌': 922, '경기': 780, '때문': 760, '공격': 754, '경우': 703, '스킬': 674, '사용': 603, '이후': 592, '정도': 571, '캐릭터': 551, '쿠키': 542, '레벨': 538, '부분': 519, '시간': 518, '다른': 481, '자신': 435, '시리즈': 432, '게임': 430, '생존자': 422, '합의': 419, '사항': 418, '토론': 418, '모습': 408, '대한': 403, '등장': 400, '페미니즘': 396, '감시자': 380, '증가': 373, '학교': 370, '비치': 365, '속도': 356, '설정': 355, '사람': 352, '내용': 346, '위해': 337, '손잡이': 334, '성우': 332, '매우': 331, '외모': 329, '여성': 328, '또한': 323, '마법': 323, '가장': 317, '아스날': 316, '하나': 310, '상황': 308, '사실': 303, '효과': 299, '상태': 299, '탄창': 298, '문제': 289, '루이스': 276, '스톡': 276, '시작': 275, '접기': 271, '모든': 271, '다크': 269, '스크루': 269, '라인': 267, '추가': 266, '코레아': 266, '한국': 265, '프레': 264, '다시': 262, '모두': 259, '이상': 258, '가지': 255, '상대': 253, '수아레스': 253, '전투': 252, '펠릭스': 250, '생각': 249, '앙헬': 249, '주의': 246, '요렌테': 246, '마르코스': 245, '트리': 244, '마스터': 244, '아이템': 239, '해독': 238, '존재': 236, '레이': 235, '마리오': 230, '주앙': 229, '티어': 229, '루카스': 226, '레이라': 226, '르마': 225, '로디': 225, '개성': 225, '몬테': 222, '다만': 221, '마드리드': 221, '타이탄': 219, '대학교': 218, '무기': 218, '감소': 218, '에르': 218, '해당': 216, '토마': 216, '헤낭': 216, '선수': 215, '최대': 215, '리페': 214, '스피드': 213, '이루': 213, '당시': 212, '티코': 211, '톨로': 211, '데미지': 211, '기본': 210, '역시': 207, '플레이': 207, '카라스': 207, '실제': 206, '블락': 206, '사울': 206, '폭발': 205, '리그': 203, '평가': 202, '인터뷰': 202, '대원': 202, '언급': 201, '코케': 201, '게스': 201, '대해': 199, '전용': 199, '능력': 198, '대학': 198, '관련': 197, '이름': 196, '남성': 196, '비아': 195, '미국': 193, '기준': 192, '마지막': 191, '공식': 191, '명단': 190, '토르': 188, '참고': 187, '이보': 187, '건축학': 186, '키어런': 185, '대전': 184, '스테판': 183, '스타': 181, '자체': 181, '인물': 180, '처음': 180, '대미지': 179, '기사': 178, '거의': 178, '교정': 176, '승리': 175, '편이': 175, '얼굴': 174, '미남': 174, '소모': 174, '수준': 173, '전체': 171, '피어': 171, '시전': 171, '머리': 169, '초월': 169, '현재': 168, '포인트': 168, '일본': 168, '타격': 168, '바로': 166, '일반': 166, '오브': 163, '여기': 162, '본인': 162, '나소드': 162, '아이': 161, '제외': 158, '기록': 158, '검사': 158, '유저': 158, '가족': 157, '버전': 157, '결과': 154, '패스': 153, '미인': 152, '이번': 152, '후반': 152, '레이저': 152, '달리': 151, '건축': 151, '일부': 150, '대부분': 150, '강화': 150, '가드': 150, '묘사': 149, '특성': 149, '계속': 148, '대신': 148, '모드': 148, '산체스': 148, '전반': 147, '통해': 147, '사건': 147, '거리': 147, '공동': 146, '위치': 146, '히메네스': 146, '조준': 146, '작품': 145, '파츠': 145, '동안': 144, '이유': 143, '포함': 143, '부상': 143, '리코': 143, '총기': 143, '교체': 142, '루크': 142, '직접': 141, '배우': 141, '피해': 141, '기사단': 141, '호세': 141, '반동': 141, '에레': 140, '판정': 139, '쿨타임': 139, '시메': 138, '액티브': 138, '그냥': 137, '파티': 137, '치료': 136, '패치': 136, '습득': 136, '대비': 134, '크게': 134, '세계': 134, '출력': 133, '사카': 133, '공과대학': 133, '다음': 132, '시브': 132, '전술': 131, '학부': 130, '원작': 130, '그대로': 129, '브르': 129, '에피소드': 129, '공개': 128, '테이프': 128, '콤보': 128, '수비': 127, '국가': 127, '사이': 126, '주장': 126, '소총': 125, '라운드': 124, '던전': 123, '선원': 123, '수도': 122, '득점': 122, '사회': 122, '전쟁': 122, '블랙': 122, '스토리': 122, '성능': 122, '보고': 121, '진행': 121, '주인공': 121, '사거리': 121, '전방': 121, '적용': 121, '레드': 121, '장면': 120, '기도': 120, '발매': 119, '아키': 119, '리스': 119, '의미': 118, '역할': 118, '제대로': 118, '가격': 118, '사이트': 118, '치아': 118, '이용': 117, '이야기': 116, '지역': 116, '만큼': 115, '포니': 115, '핸드': 115, '작화': 115, '거나': 114, '세르': 114, '시절': 114, '제국': 114, '해제': 114, '바이오하자드': 114, '의자': 114, '서울': 113, '다년': 113, '발생': 113, '스킨': 113, '자기': 111, '이적': 111, '보호': 111, '자주': 111, '영상': 110, '단계': 110, '방송': 110, '유닛': 110, '지금': 109, '운동': 109, '주체': 109, '판타지': 108, '정보': 108, '렉스': 108, '아버지': 107, '활약': 107, '이기': 107, '이반': 107, '제트': 107, '카메': 107, '사격': 107, '포워드': 107, '멤버': 106, '보이': 106, '자리': 106, '마찬가지': 106, '영향': 106, '라카': 106, '패드': 106, '출전': 105, '조금': 105, '로만': 105, '마누': 105, '틀레': 105, '체력': 105, '계열': 105, '초반': 104, '선발': 104, '반대': 104, '개발': 104, '리플': 104, '각성': 104, '패스트': 104, '주변': 103, '아예': 103, '서브': 103, '발동': 103, '워존': 103, '비교': 102, '사례': 102, '제작': 102, '좀비' ...

# %%
# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"

# 텍스트 파일을 오픈합니다.
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
# 나무위키 페이지에 맞는 불용어를 추가합니다.
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장',
                       '줄거리', '요소', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물', 
                       '이름', '년월']
for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
#!pip install pytagcloud pygame simplejson

# %%
import random
import pytagcloud
import webbrowser
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

# %%
# 생성한 이미지를 주피터 노트북상에서 출력합니다.
from IPython.display import Image
Image(filename='wordcloud.jpg')

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'title_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='title_wordcloud.jpg')

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'category_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='category_wordcloud.jpg')
